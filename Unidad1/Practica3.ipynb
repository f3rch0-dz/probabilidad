# %% [markdown]
# <a href="https://colab.research.google.com/github/f3rch0-dz/probabilidad/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Probabilidad y estadistica**
#
# ## **Unidad 1**
#
# ### **Practica 3. Tabla de frecuencia y regla de Sturges..**
#
# ### Docente: *Dr. Jose Gabriel Rodriguez Rivas*
#
# ### Alumno: Diaz Renteria Luis Fernando
#
# ### *Instituto Tecnologico de Durango*

# %%
# Basado en el libro estadistica para administracion P.12
# Creamos una lista vacia que representa la edad de 100 personas

import random
edades = []

# Hacemos un ciclo para generar 100 numeros aleatorios que representen la edad de las personas

for i in range(100):
  # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable
  # numero_aleatorio

  numero_aleatorio = random.randint( 18, 70)
  # agregamos el numero aleatorio a la lista de valores
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [19, 38, 52, 68, 48, 31, 64, 53, 58, 40, 61, 70, 41, 62, 27, 34, 37, 56, 68, 62, 65, 26, 22, 25, 31, 30, 33, 58, 37, 55, 57, 20, 29, 22, 62, 22, 59, 19, 61, 19, 30, 68, 50, 49, 55, 49, 23, 66, 62, 42, 32, 28, 25, 46, 48, 56, 23, 20, 47, 56, 43, 60, 47, 70, 18, 37, 37, 59, 37, 27, 53, 35, 68, 59, 60, 20, 40, 47, 49, 24, 47, 69, 23, 67, 46, 69, 49, 40, 44, 58, 31, 47, 47, 23, 69, 42, 25, 56, 19, 26]

# %%
import pandas as pd

# %%
# Crear un dataFrame de pandas con los numereos aleatorios

df = pd.DataFrame(edades, columns=[ 'Edad'])
df.head()
# Out:
#    Edad
# 0    19
# 1    38
# 2    52
# 3    68
# 4    48

# %%
# Calcular la tabla de distribucion de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = [ 'Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribucion de frecuencias
print("Tabla de distribucion de Frecuencias")
tabla_frecuencias
# Out:
# Tabla de distribucion de Frecuencias
#     Edad  Frecuencia
# 40    18           1
# 4     19           4
# 8     20           3
# 9     22           3
# 7     23           4
# 43    24           1
# 10    25           3
# 24    26           2
# 25    27           2
# 39    28           1
# 31    29           1
# 26    30           2
# 11    31           3
# 38    32           1
# 36    33           1
# 34    34           1
# 42    35           1
# 1     37           5
# 28    38           1
# 12    40           3
# 30    41           1
# 16    42           2
# 41    43           1
# 45    44           1
# 17    46           2
# 0     47           6
# 19    48           2
# 3     49           4
# 32    50           1
# 29    52           1
# 18    53           2
# 23    55           2
# 6     56           4
# 33    57           1
# 13    58           3
# 15    59           3
# 22    60           2
# 20    61           2
# 2     62           4
# 27    64           1
# 35    65           1
# 37    66           1
# 44    67           1
# 5     68           4
# 14    69           3
# 21    70           2

# %%
# Calcular la frecuencia relativa

tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia'] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 40    18           1           0.01
# 4     19           4           0.04
# 8     20           3           0.03
# 9     22           3           0.03
# 7     23           4           0.04
# 43    24           1           0.01
# 10    25           3           0.03
# 24    26           2           0.02
# 25    27           2           0.02
# 39    28           1           0.01
# 31    29           1           0.01
# 26    30           2           0.02
# 11    31           3           0.03
# 38    32           1           0.01
# 36    33           1           0.01
# 34    34           1           0.01
# 42    35           1           0.01
# 1     37           5           0.05
# 28    38           1           0.01
# 12    40           3           0.03
# 30    41           1           0.01
# 16    42           2           0.02
# 41    43           1           0.01
# 45    44           1           0.01
# 17    46           2           0.02
# 0     47           6           0.06
# 19    48           2           0.02
# 3     49           4           0.04
# 32    50           1           0.01
# 29    52           1           0.01
# 18    53           2           0.02
# 23    55           2           0.02
# 6     56           4           0.04
# 33    57           1           0.01
# 13    58           3           0.03
# 15    59           3           0.03
# 22    60           2           0.02
# 20    61           2           0.02
# 2     62           4           0.04
# 27    64           1           0.01
# 35    65           1           0.01
# 37    66           1           0.01
# 44    67           1           0.01
# 5     68           4           0.04
# 14    69           3           0.03
# 21    70           2           0.02

# %%
# Calcular la frecuencia porcentual

tabla_frecuencias['Frec Porcentual'] = tabla_frecuencias['Frecuencia'] / 100*100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual
# 40    18           1           0.01              1.0
# 4     19           4           0.04              4.0
# 8     20           3           0.03              3.0
# 9     22           3           0.03              3.0
# 7     23           4           0.04              4.0
# 43    24           1           0.01              1.0
# 10    25           3           0.03              3.0
# 24    26           2           0.02              2.0
# 25    27           2           0.02              2.0
# 39    28           1           0.01              1.0
# 31    29           1           0.01              1.0
# 26    30           2           0.02              2.0
# 11    31           3           0.03              3.0
# 38    32           1           0.01              1.0
# 36    33           1           0.01              1.0
# 34    34           1           0.01              1.0
# 42    35           1           0.01              1.0
# 1     37           5           0.05              5.0
# 28    38           1           0.01              1.0
# 12    40           3           0.03              3.0
# 30    41           1           0.01              1.0
# 16    42           2           0.02              2.0
# 41    43           1           0.01              1.0
# 45    44           1           0.01              1.0
# 17    46           2           0.02              2.0
# 0     47           6           0.06              6.0
# 19    48           2           0.02              2.0
# 3     49           4           0.04              4.0
# 32    50           1           0.01              1.0
# 29    52           1           0.01              1.0
# 18    53           2           0.02              2.0
# 23    55           2           0.02              2.0
# 6     56           4           0.04              4.0
# 33    57           1           0.01              1.0
# 13    58           3           0.03              3.0
# 15    59           3           0.03              3.0
# 22    60           2           0.02              2.0
# 20    61           2           0.02              2.0
# 2     62           4           0.04              4.0
# 27    64           1           0.01              1.0
# 35    65           1           0.01              1.0
# 37    66           1           0.01              1.0
# 44    67           1           0.01              1.0
# 5     68           4           0.04              4.0
# 14    69           3           0.03              3.0
# 21    70           2           0.02              2.0

# %%
#Calcular la frecuencia acumulada

tabla_frecuencias['Frec Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec Porcentual  Frec Acumulada
# 40    18           1           0.01              1.0               1
# 4     19           4           0.04              4.0               5
# 8     20           3           0.03              3.0               8
# 9     22           3           0.03              3.0              11
# 7     23           4           0.04              4.0              15
# 43    24           1           0.01              1.0              16
# 10    25           3           0.03              3.0              19
# 24    26           2           0.02              2.0              21
# 25    27           2           0.02              2.0              23
# 39    28           1           0.01              1.0              24
# 31    29           1           0.01              1.0              25
# 26    30           2           0.02              2.0              27
# 11    31           3           0.03              3.0              30
# 38    32           1           0.01              1.0              31
# 36    33           1           0.01              1.0              32
# 34    34           1           0.01              1.0              33
# 42    35           1           0.01              1.0              34
# 1     37           5           0.05              5.0              39
# 28    38           1           0.01              1.0              40
# 12    40           3           0.03              3.0              43
# 30    41           1           0.01              1.0              44
# 16    42           2           0.02              2.0              46
# 41    43           1           0.01              1.0              47
# 45    44           1           0.01              1.0              48
# 17    46           2           0.02              2.0              50
# 0     47           6           0.06              6.0              56
# 19    48           2           0.02              2.0              58
# 3     49           4           0.04              4.0              62
# 32    50           1           0.01              1.0              63
# 29    52           1           0.01              1.0              64
# 18    53           2           0.02              2.0              66
# 23    55           2           0.02              2.0              68
# 6     56           4           0.04              4.0              72
# 33    57           1           0.01              1.0              73
# 13    58           3           0.03              3.0              76
# 15    59           3           0.03              3.0              79
# 22    60           2           0.02              2.0              81
# 20    61           2           0.02              2.0              83
# 2     62           4           0.04              4.0              87
# 27    64           1           0.01              1.0              88
# 35    65           1           0.01              1.0              89
# 37    66           1           0.01              1.0              90
# 44    67           1           0.01              1.0              91
# 5     68           4           0.04              4.0              95
# 14    69           3           0.03              3.0              98
# 21    70           2           0.02              2.0             100

# %% [markdown]
# # **Regla de sturges**
# #### 1- Es una regla que sirve para calcular el numero de clases o intervalos idoneos en los que se debe dividir un conjunto de datos
#
# #### 2.- Establece que el numero de clases es igual a uno mas el logaritmo en base dos del numero total de datos
#
# #### **c = 1 + log2 (N)**
#
# #### donde N es el tamaño de la muestra

# %%
# Importamos la libreria math de funciones matematicas
import math

# %%
# Volvemos a usar la lista edades
print(edades)
# Out:
# [19, 38, 52, 68, 48, 31, 64, 53, 58, 40, 61, 70, 41, 62, 27, 34, 37, 56, 68, 62, 65, 26, 22, 25, 31, 30, 33, 58, 37, 55, 57, 20, 29, 22, 62, 22, 59, 19, 61, 19, 30, 68, 50, 49, 55, 49, 23, 66, 62, 42, 32, 28, 25, 46, 48, 56, 23, 20, 47, 56, 43, 60, 47, 70, 18, 37, 37, 59, 37, 27, 53, 35, 68, 59, 60, 20, 40, 47, 49, 24, 47, 69, 23, 67, 46, 69, 49, 40, 44, 58, 31, 47, 47, 23, 69, 42, 25, 56, 19, 26]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad' : edades})
df
# Out:
#     Edad
# 0     19
# 1     38
# 2     52
# 3     68
# 4     48
# ..   ...
# 95    42
# 96    25
# 97    56
# 98    19
# 99    26
#
# [100 rows x 1 columns]

# %%
# Calcular el numero de intervalos utilizando la regla de sturges
n = len(edades)
K = int( 1 + math.log2(n))
print("Valor de n = ", n , " \nNumero de intervalos =", K)
# Out:
# Valor de n =  100
# Numero de intervalos = 7

# %%
# Crear la tabla de frecuencia

tabla_frecuencia = pd.cut( df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (17.947, 25.429]    19
# 1  (55.143, 62.571]    19
# 2  (40.286, 47.714]    13
# 3    (62.571, 70.0]    13
# 4  (25.429, 32.857]    12
# 5  (32.857, 40.286]    12
# 6  (47.714, 55.143]    12

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (17.947, 25.429]    19
# 4  (25.429, 32.857]    12
# 5  (32.857, 40.286]    12
# 2  (40.286, 47.714]    13
# 6  (47.714, 55.143]    12
# 1  (55.143, 62.571]    19
# 3    (62.571, 70.0]    13

# %%
# Generar columnas, siguientes

tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Por Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

#Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 0  (17.947, 25.429]    19      0.19       19.0       19           19
# 4  (25.429, 32.857]    12      0.12       12.0       31           31
# 5  (32.857, 40.286]    12      0.12       12.0       43           43
# 2  (40.286, 47.714]    13      0.13       13.0       56           56
# 6  (47.714, 55.143]    12      0.12       12.0       68           68
# 1  (55.143, 62.571]    19      0.19       19.0       87           87
# 3    (62.571, 70.0]    13      0.13       13.0      100          100
#
#    Frec Por Ac
# 0         19.0
# 4         31.0
# 5         43.0
# 2         56.0
# 6         68.0
# 1         87.0
# 3        100.0

# %%
import random
import matplotlib.pyplot as plt  #Libreria para graficar
from statistics import *

plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
# Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
